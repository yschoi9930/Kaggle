# %% [markdown]
# # Heart Disease Classification

# %% [markdown]
# # 0. Github Push

# %%
cd '/content/drive/MyDrive/Kaggle'

# %%
# !git config --global user.email '(yschoi9930@gmail.com)'
# !git config --global user.name '(yschoi9930)'

# %%
# !git remote remove origin

# %%
# !git remote add origin 'https://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@github.com/yschoi9930/Kaggle-Practice'

# %%
# !git pull origin mater

# %%
# !git add .

# %%
# !git commit -m 'Add EDA'

# %%
# !git push origin master

# %% [markdown]
# ## 1. Importing libraries & Mounting Drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pl
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 2. Reading the dataset

# %%
df = pd.read_csv('/content/drive/MyDrive/Kaggle/heart_2020_cleaned.csv')
df.head()

# %% [markdown]
# ## 3. Cleaning Dataset
# - Remove null values
# - Replace from object type to int
# - Categorize Some values

# %%
df.isnull().any()

# %% [markdown]
# There are no null values

# %%
df.info()

# %%
df.columns

# %%
df_replace = df[df.columns].replace({'Yes':1, 'No':0, 'Male':1, 'Female':0} )

# %%
df_replace.head()

# %%
df_replace['GenHealth'].value_counts()

# %%
df_replace['GenHealth'].unique()

# %%
df_replace['GenHealth'].value_counts().index

# %%
df_replace['GenHealth'] = df_replace['GenHealth'].replace({'Very good':4, 'Fair':2, 'Good':3, 'Poor':1, 'Excellent':5})

# %%
df_replace.describe()

# %% [markdown]
# ## 4. EDA

# %%
##

# %%
df['HeartDisease'].value_counts()

# %%
fig = df['HeartDisease'].value_counts().plot(kind = 'bar', color = ['yellow', 'green'])
fig.set_xticklabels(labels = ['No Heartdisease','Heartdisease'], rotation = 0)
plt.title('Heartdia')
