# %% [markdown]
# # Heart Disease Prediction

# %% [markdown]
# ## 1. Importing libraries & Mounting Drive

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 2. Reading the dataset

# %%
df = pd.read_csv('/content/drive/MyDrive/Kaggle/heart_2020_cleaned.csv')
df.head()

# %% [markdown]
# ## 3. EDA

# %%
df.describe().T

# %%
df.isnull().any()

# %%
df.info()

# %% [markdown]
# - There are no null values

# %%
df.nunique()

# %%
# !git clone https://yschoi9930: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@github.com/yschoi9930/Kaggle.git

# %%
cd '/content/drive/MyDrive/Kaggle'

# %%
# !git config --global user.email '(yschoi9930@gmail.com)'
# !git config --global user.name '(yschoi9930)'

# %%
# !git add .

# %%
# !git commit -m 'First Commit'

# %%
# !git push origin master
